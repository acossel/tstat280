# %% [markdown]
# ### Analyzing Store Sales
#
# A small store records the number of items sold for several products in one day.
#
# ```python
# sales = {
#     "Apples": [12, 15, 10],
#     "Bananas": [8, 9, 11],
#     "Oranges": [14, 16, 13]
# }
# ```
#
# Each list represents the number of items sold in three different hours of the day.
#
# #### Part 1
#
# Print the number of bananas sold during the second hour.
#
# #### Part 2
#
# Write a function called `total_sales` that takes a list of numbers and returns the total number of items sold.
#
# #### Part 3
#
# Use a for loop to compute the total sales for each product using your function.
#
# Print the results like this:
#
# ```python
# Apples total: ...
# Bananas total: ...
# Oranges total: ...
# ```
#
# #### Part 4
#
# If a product sold more than 35 items total, print:
#
# - High sales for `product`
#
# Otherwise print:
#
# - Low sales for `product`

# %%
import numpy as np

sales = {
    "Apples": [12, 15, 10],
    "Bananas": [8, 9, 11],
    "Oranges": [14, 16, 13]
}

# Part 1
# Print bananas sold in the second hour


# Part 2
def total_sales(numbers):
    pass # replace with your code here

# Part 3 and 4
for product in sales:
    total = total_sales(sales[product])
    print(product, "total:", total)

    # write the conditional here
# Out:
# Apples total: None
# Bananas total: None
# Oranges total: None
