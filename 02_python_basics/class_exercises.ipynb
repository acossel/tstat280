# %% [markdown]
# ### Exercise 1
#
# You are given the following list representing the average monthly temperatures (°F) for the first six months of the year.
#
# Your list slicing to find the following:
#
# 1. January's temperature
# 2. March's temperature
# 3. February, March, and April's temperatures

# %%
temps = [42, 45, 51, 58, 65, 72]

# Print January's temperature

# Print March's temperature

# Print February, March, and April's temperatures

# %% [markdown]
# ### Exercise 2
#
# You are given a dictionary that stores the number of students in different majors.
#
# ```python
# students = {
#     "Data Science": 120,
#     "Computer Science": 200,
#     "Mathematics": 80,
#     "Statistics": 60
# }
# ```
#
# Write Python code that:
#
# 1. Prints the number of students in Computer Science.
# 2. Prints the number of students in Statistics.
# 3. Calculates and prints the total number of students in Data Science and Mathematics.

# %%
students = {
    "Data Science": 120,
    "Computer Science": 200,
    "Mathematics": 80,
    "Statistics": 60
}

total = 0

# Print the number of Computer Science students

# Print the number of Statistics students

# Calculate the total number of Data Science and Mathematics students

print("Total:", total)
# Out:
# Total: 0

# %% [markdown]
# ### Exercise 3
#
# A store gives customers a discount based on their purchase amount.
#
# - If the purchase is \$100 or more, the customer gets a 20\% discount.
# - If the purchase is \\$50 to \$99, the customer gets a 10\% discount.
# - If the purchase is less than \$50, there is no discount.
#
# Write Python code that:
#
# 1. Stores the purchase amount in a variable called purchase.
# 2. Uses conditional statements (if, elif, else) to determine the correct discount.
# 3. Prints the final price after the discount.

# %%
purchase = 80  # purchase amount in dollars

final_price = 0

# Write your conditional statements below

print("Final price:", final_price)
# Out:
# Final price: 0

# %% [markdown]
# ### Exercise 4
#
# You are given a list of daily step counts recorded by a fitness tracker.
#
# ```python
# steps = [4500, 8200, 7600, 10000, 5400]
# ```
#
# Write Python code that uses a for loop to calculate the total number of steps taken during the week.
#
# Your code should:
#
# 1. Loop through each value in the steps list.
# 2. Add each value to a variable called total_steps.
# 3. Print the final total.

# %%
steps = [4500, 8200, 7600, 10000, 5400]

total_steps = 0

# Write your for loop below

print("Total steps:", total_steps)
# Out:
# Total steps: 0

# %% [markdown]
# ### Exercise 5
#
# You are given a list of exam scores:
#
# ```python
# scores = [72, 88, 95, 67, 80, 91]
# ```
#
# Write a list comprehension that creates a new list called `high_scores` containing only the scores that are greater than or equal to 90.
#
# Then print the new list.

# %%
scores = [72, 88, 95, 67, 80, 91]

# Create a list of scores >= 90 using a list comprehension
high_scores = []

print(high_scores)
# Out:
# []

# %% [markdown]
# ### Exercise 6
#
# In health science, Body Mass Index (BMI) is often used to estimate whether a person’s weight is appropriate for their height.
#
# Write a function called `calculate_bmi` that:
#
# 1. Takes two inputs:
#
#     - `weight_kg` (weight in kilograms)
#     - `height_m` (height in meters)
#
# 2. Calculates the person's BMI.
#
# 3. Returns the BMI value.
#
# Use the following formula:
#
# BMI = $\frac{\text{weight (kg)}}{\text{height (m)}^2}$

# %%
def calculate_bmi(weight_kg, height_m):
    pass # Replace with your code

bmi = calculate_bmi(70, 1.75)

print("BMI:", bmi)
# Out:
# BMI: None

# %% [markdown]
# ### Exercise 7
#
# A warehouse stores packages in large shipping crates.
# Each crate can hold 12 packages.
#
# A shipment arrives containing 95 packages. The warehouse wants to know how many full crates can be filled.
#
# Write Python code that:
#
# 1. Imports the `math` library.
# 2. Uses `math.floor()` to calculate the number of full crates that can be filled.
# 3. Prints the result.

# %%
packages = 95
packages_per_crate = 12

# Import the math library

# Calculate the number of full crates
full_crates = 0

print("Number of full crates:", full_crates)
# Out:
# Number of full crates: 0

# %% [markdown]
# ### Exercise 8
#
# A researcher is studying voter turnout in several elections.
#
# First, they record turnout percentages for four elections in a 1D NumPy array. Then, they store turnout data for three different states across four elections in a 2D NumPy array.
#
# Write Python code that:
#
# 1. Imports NumPy.
# 2. Creates the following 1D array of turnout percentages:
# ```python
# [58, 62, 65, 60]
# ```
# 3. Computes and prints the average turnout across all four elections.
# 4. Prints the turnout for the second election.
# 5. Creates the following 2D array representing turnout percentages for 3 states (rows) across 4 elections (columns):
# ```python
# [[58, 62, 65, 60],
#  [55, 59, 61, 57],
#  [63, 67, 70, 66]]
# ```
# 6. Prints the turnout for the second state in the third election.
# 7. Computes and prints the average turnout for each state.

# %%
# Import numpy

# Create the 1D array

# Compute average voter turnout

# Print the turnout for the second election

# Create the 2D array

# Print the turnout for the second state in the third election

# Compute average turnout for each state

# %% [markdown]
# ### Exercise 9
#
# A store records the number of units sold for several products in one day.
#
# ```python
# sales = [45, 30, 52, 41, 38]
# ```
#
# Sometimes analysts create a NumPy array as a placeholder before entering the final data.
#
# In this exercise, you will use Jupyter Notebook’s documentation tools to learn about the function np.ndarray.fill.
#
# Instructions:
#
# 1. Import NumPy.
# 2. Create a NumPy array called `sales_array` with 5 zeros.
# 3. Use Jupyter’s help feature to view the documentation for `np.ndarray.fill`.
# 4. Use `.fill()` to fill the array with the value 50 (representing a placeholder sales value).
# 5. Print the array.

# %%
import numpy as np

# Create an array of five zeros
sales_array = np.array([])

# Use Jupyter help to view the documentation for np.ndarray.fill

# Fill the array with the value 50

print(sales_array)
# Out:
# []
