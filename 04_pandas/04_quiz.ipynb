# %% [markdown]
# ### Quiz

# %% [markdown]
# #### Part 1
#
# Read in the data found in `diamonds.csv` and then print a summary of the DataFrame that shows column names, non-null counts, and data types.

# %%
import pandas as pd

df = pd.read_csv("../data/diamonds.csv")
print(df.info)
print(df.describe)
print(df.dtypes)
# Out:
# <bound method DataFrame.info of        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]>
# <bound method NDFrame.describe of        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]>
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %% [markdown]
# #### Part 2
#
# Select only the price and carat columns from the DataFrame.

# %%
df[["price", "carat"]]
# Out:
#        price  carat
# 0        326   0.23
# 1        326   0.21
# 2        327   0.23
# 3        334   0.29
# 4        335   0.31
# ...      ...    ...
# 53935   2757   0.72
# 53936   2757   0.72
# 53937   2757   0.70
# 53938   2757   0.86
# 53939   2757   0.75
#
# [53940 rows x 2 columns]

# %% [markdown]
# #### Part 3
#
# Create a new column called `box_volume` that is the product of dimensions `x`, `y`, and `z`. Then display the new DataFrame.

# %%
df["box_volume"]=(df["x"]*df["y"]*df["z"])
print(df)
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price  \
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
#        box_volume
# 0       38.202030
# 1       34.505856
# 2       38.076885
# 3       46.724580
# 4       51.917250
# ...           ...
# 53935  115.920000
# 53936  118.110175
# 53937  114.449728
# 53938  140.766120
# 53939  124.568444
#
# [53940 rows x 11 columns]

# %% [markdown]
# #### Part 4
#
# Use either `map` or `apply` (whichever is more appropriate) to create a new column called `good_deal` which is 1 if the cut is Ideal and the price is below 500. Then display the new DataFrame.

# %%
df['good_deal'] = df.apply(lambda row: 1 if row['cut'] == 'Ideal' and row['price'] < 500 else 0, axis=1)
print(df)
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price  \
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
#        good_deal
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 53935          0
# 53936          0
# 53937          0
# 53938          0
# 53939          0
#
# [53940 rows x 11 columns]

# %% [markdown]
# #### Part 5
#
# Find and output the maximum carat value for each color.

# %%
df.groupby("carat")["color"].max()
# Out:
# carat
# 0.20    F
# 0.21    E
# 0.22    F
# 0.23    J
# 0.24    J
#        ..
# 4.00    I
# 4.01    J
# 4.13    H
# 4.50    J
# 5.01    J
# Name: color, Length: 273, dtype: object

# %% [markdown]
# #### Part 6
#
# Merge the `movies` and `ratings` DataFrames so that all information about the movies in `movies` is kept even if information about their rating is not available in `ratings`. Display the merged DataFrame.

# %%
movies = pd.DataFrame({
    "movie_id": [10, 11, 12, 13],
    "title": ["Inception", "Titanic", "Avatar", "Jaws"]
})

ratings = pd.DataFrame({
    "movie_id": [10, 11, 14],
    "rating": [8.8, 7.8, 6.5]
})

# %%
df_mr=movies.merge(ratings, how="left")
print(df_mr)
# Out:
#    movie_id      title  rating
# 0        10  Inception     8.8
# 1        11    Titanic     7.8
# 2        12     Avatar     NaN
# 3        13       Jaws     NaN
