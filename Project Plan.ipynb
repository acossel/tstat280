# %% [markdown]
# Who is the stakeholder and what do they want to accomplish?
# Maya is the stakeholder and she wants to give consumers more clarity on housing prices
#
# Is this a supervised learning or unsupervised learning problem? If it is a supervised learning problem, does it sound like a regression or classification task?
# It is a supervised learning problem and is a classification task
#
# Which of the individuals sounds like a data engineer?
# Luis
# Where do the data come from?
# Details about homes like size, number of rooms and previous sale prices, crime reports, broader neighborhood level indicators, infomation about nearby places
# What problems are there with the data? Missing values, inconsistent formatting, duplicates, different levels of detail
# How will you address any of these problems?
# Insert missing values with mean values or other methods, change the data in a column to use the same object type, detect duplicates in the data and remove them, standardize the dataframe columns for units
#
# Which of the individuals sounds like a data analyst?
# Aisha
# What are some trends they've noticed in the past?
# Some homes behave differently depending on the neighborhood/location, square footage and number of bedrooms matter but are complex
# What are some suggestions they have for future data analyses?
# Look at connections between price and size, number of rooms and lot size, compare prices in different locations, see if the distance from other places causes a change in price, and check if there are any extreme values that may skew the results
#
# Which of the individuals sounds like a machine learning engineer?
# Ethan
# What are some things to consider when building the model?
# Check how well the model's prediction matches with the actual data and test the model on new data
# What are some things to consider when presenting the model for others to use?
# Keep things simple, ensure everything is clear
# What are some things you want to account for when deploying the model?
# Response speed, reliable results, and a way to account for incomplete information
#
# Which of the individuals sounds like a subject matter expert?
# Dr. Chen
# What variables will be useful for prediction?
# Location and distance from nearby places, crime levels, feature combinations/impactfulness
# What variables aren't readily available that might require extra effort to construct?
# Similar sizes may change price heavily depending on condition or location, some features may matter more than others,
